# %% [markdown]
# # 04 因子检验
#
# 输入：`data/sample/*.csv`。输出：`reports/figures/ic_summary.csv`、`group_returns.csv`、`factor_corr.csv` 和相关 PNG 图。目标收益为未来 20 个交易日收益。

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = next(p for p in ROOT.parents if (p / 'src').exists())
sys.path.insert(0, str(ROOT / 'src'))
from ashare_factor_research.pipeline import run_sample_pipeline
result = run_sample_pipeline(ROOT / 'data' / 'sample', ROOT / 'reports' / 'figures')
print(result['ic_table'].sort_values('mean', ascending=False).head().to_string())
print(result['group_returns'].tail().to_string())
